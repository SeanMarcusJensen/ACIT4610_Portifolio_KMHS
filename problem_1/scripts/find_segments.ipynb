# %%
import os
import pandas as pd

DATA_DIR = os.path.join(os.getcwd(), '..', 'data', 'raw')
VOLUME_DATA_FILE = os.path.join(DATA_DIR, 'Traffic_Volume_Counts_20240909.csv')

volume_data = pd.read_csv(VOLUME_DATA_FILE)
# Out:
# /Users/seanjensen/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 SPEED_DATA_FILE = os.path.join(DATA_DIR, 'NYC Traffic Speeds 20241006.csv')
#       6 VOLUME_DATA_FILE = os.path.join(DATA_DIR, 'Traffic_Volume_Counts_20240909.csv')
# ----> 8 speed_data = pd.read_csv(SPEED_DATA_FILE)
#       9 volume_data = pd.read_csv(VOLUME_DATA_FILE)
#
# ...

# %%
speed_data.head()
# Out:
#     ID  SPEED  TRAVEL_TIME  STATUS              DATA_AS_OF  LINK_ID  \
# 0  434  60.27           53       0  01/01/2020 12:48:11 PM  4616212
# 1  433  53.43          140       0  01/01/2020 12:48:11 PM  4616215
# 2    4  19.26          168       0  01/01/2020 12:48:11 PM  4616338
# 3  377  59.03           66       0  01/01/2020 12:48:11 PM  4616195
# 4  378  59.03           45       0  01/01/2020 12:48:11 PM  4616197
#
#                                          LINK_POINTS        OWNER  \
# 0  40.6020904,-74.1877 40.600331,-74.18943 40.597...  NYC_DOT_LIC
# 1  40.52561,-74.23039 40.5258705,-74.22618 40.526...  NYC_DOT_LIC
# 2  40.7607,-74.002141 40.76212,-74.91 40.76335,-7...  NYC_DOT_LIC
# 3  40.61486,-74.15738 40.60931,-74.15012 40.60846...  NYC_DOT_LIC
# 4  40.6210105,-74.168861 40.6207604,-74.168 40.61...  NYC_DOT_LIC
#
#    TRANSCOM_ID        BOROUGH                                  LINK_NAME
# 0      4616212  Staten Island          WSE N VICTORY BLVD - SOUTH AVENUE
# ...

# %%
speed_data['LINK_POINTS'][0].split(' ')
# Out:
# ['40.6020904,-74.1877',
#  '40.600331,-74.18943',
#  '40.59783,-74.19099',
#  '40.592071,-74.193131',
#  '40.5907404,-74.19333',
#  '40.5902,-74.19332']

# %%
volume_data.head()
# Out:
#    ID  SegmentID  Roadway Name         From                To Direction  \
# 0   1      15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 1   2      15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 2   3      15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 3   4      15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
# 4   5      15540  BEACH STREET  UNION PLACE  VAN DUZER STREET        NB
#
#          Date  12:00-1:00 AM  1:00-2:00AM  2:00-3:00AM  ...  2:00-3:00PM  \
# 0  01/09/2012           20.0         10.0         11.0  ...        104.0
# 1  01/10/2012           21.0         16.0          8.0  ...        102.0
# 2  01/11/2012           27.0         14.0          6.0  ...        115.0
# 3  01/12/2012           22.0          7.0          7.0  ...         71.0
# 4  01/13/2012           31.0         17.0          7.0  ...        113.0
#
#    3:00-4:00PM  4:00-5:00PM  5:00-6:00PM  6:00-7:00PM  7:00-8:00PM  \
# ...
